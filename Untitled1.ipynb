# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
uber_df = pd.read_csv ("data.xlsx.csv")
uber_df.head(5)
# Out:
#        Date/Time      Lat      Lon    Base
# 0  9/1/2014 0:01  40.2201 -74.0021  B02512
# 1  9/1/2014 0:01  40.7500 -74.0027  B02512
# 2  9/1/2014 0:03  40.7559 -73.9864  B02512
# 3  9/1/2014 0:06  40.7450 -73.9889  B02512
# 4  9/1/2014 0:11  40.8145 -73.9444  B02512

# %%
uber_df.tail()
# Out:
#                Date/Time      Lat      Lon    Base
# 1028131  9/30/2014 22:57  40.7668 -73.9845  B02764
# 1028132  9/30/2014 22:57  40.6911 -74.1773  B02764
# 1028133  9/30/2014 22:58  40.8519 -73.9319  B02764
# 1028134  9/30/2014 22:58  40.7081 -74.0066  B02764
# 1028135  9/30/2014 22:58  40.7140 -73.9496  B02764

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028136 entries, 0 to 1028135
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Date/Time  1028136 non-null  object
#  1   Lat        1028136 non-null  float64
#  2   Lon        1028136 non-null  float64
#  3   Base       1028136 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 23.5+ MB

# %%
uber_df['Date/Time'] = pd.to_datetime (uber_df['Date/Time']) 
uber_df["Day"] = uber_df['Date/Time'].apply(lambda x: x.day)
uber_df["Hour"] = uber_df['Date/Time'].apply(lambda x: x.hour)
uber_df['Weekday'] = uber_df['Date/Time'].apply(lambda x: x.weekday())
uber_df.head(5)
# Out:
#             Date/Time      Lat      Lon    Base  Day  Hour  Weekday
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512    1     0        0
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512    1     0        0
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512    1     0        0
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512    1     0        0
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512    1     0        0

# %%
fig,ax= plt.subplots(figsize =(12,6))
plt.hist(uber_df.Day, width =0.6, bins = 30 )
plt.title("Density of trips perday ", fontsize = 16)
plt.xlabel("Day", fontsize= 14)
plt.ylabel("Density of riders", fontsize = 14 )
# Out:
# Text(0, 0.5, 'Density of riders')

# %%
fig,ax = plt.subplots(figsize = (12,6))
plt.hist(uber_df.Weekday, width = 0.6, range = (0,6),  bins = 7, color = "green")
plt.title("x",  fontsize = 16)
plt.xlabel("Weekday", fontsize = 14)
plt.ylabel("Density of riders", fontsize = 14)
# Out:
# Text(0, 0.5, 'Density of riders')

# %%
fig,ax = plt.subplots(figsize = (12,6))
x= uber_df.Lon
y= uber_df.Lat
plt.scatter(x,y, color="purple")
plt.title("Density of trips per Hour", fontsize=16)
plt.xlabel("Hour", fontsize=14)
plt.ylabel("Density of rides", fontsize=14)
# Out:
# Text(0, 0.5, 'Density of rides')
